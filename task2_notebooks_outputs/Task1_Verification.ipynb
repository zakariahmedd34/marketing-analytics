# %% [markdown]
# # Task 1 Output Verification
#
# should contain:
# - cleaned data
# - engineered features
# - removed unnecessary columns
# - handled missing values
# - cleaned categorical values

# %%
import pandas as pd

df = pd.read_csv("data_cleaned.csv")
df.head()
# Out:
#     Education Marital_Status   Income  Kidhome  Teenhome Dt_Customer  Recency  \
# 0  Graduation         Single  58138.0        0         0  2012-09-04       58
# 1  Graduation         Single  46344.0        1         1  2014-03-08       38
# 2  Graduation       Together  71613.0        0         0  2013-08-21       26
# 3  Graduation       Together  26646.0        1         0  2014-02-10       26
# 4         PhD        Married  58293.0        1         0  2014-01-19       94
#
#    MntWines  MntFruits  MntMeatProducts  ...  AcceptedCmp2  Complain  \
# 0       635         88              546  ...             0         0
# 1        11          1                6  ...             0         0
# 2       426         49              127  ...             0         0
# 3        11          4               20  ...             0         0
# 4       173         43              118  ...             0         0
#
#    Response  Total_Spending  Total_Purchases  Average_Spend  Family_Size  Age  \
# ...

# %%
print("Shape:", df.shape)
# Out:
# Shape: (2209, 32)

# %%
print(df.columns.tolist())
# Out:
# ['Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Complain', 'Response', 'Total_Spending', 'Total_Purchases', 'Average_Spend', 'Family_Size', 'Age', 'Engagement', 'Spending_Ratio']

# %%
expected_present = [
    "Income",
    "Marital_Status",
    "Education",
    "Recency",
    "Kidhome",
    "Teenhome",
    "Dt_Customer",
    "Total_Spending",
    "Total_Purchases",
    "Average_Spend",
    "Family_Size",
    "Age",
    "Engagement",
    "Spending_Ratio"
]

for col in expected_present:
    print(col, "->", col in df.columns)
# Out:
# Income -> True
# Marital_Status -> True
# Education -> True
# Recency -> True
# Kidhome -> True
# Teenhome -> True
# Dt_Customer -> True
# Total_Spending -> True
# Total_Purchases -> True
# Average_Spend -> True
# Family_Size -> True
# Age -> True
# Engagement -> True
# Spending_Ratio -> True

# %%
expected_absent = [
    "ID",
    "Year_Birth",
    "Z_CostContact",
    "Z_Revenue"
]

for col in expected_absent:
    print(col, "->", col in df.columns)
# Out:
# ID -> False
# Year_Birth -> False
# Z_CostContact -> False
# Z_Revenue -> False

# %%
missing = df.isnull().sum()
print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 183

# %%
df.dtypes
# Out:
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Complain                 int64
# Response                 int64
# Total_Spending           int64
# Total_Purchases          int64
# Average_Spend          float64
# Family_Size              int64
# Age                      int64
# ...

# %%
check_cols = [
    "Income",
    "Age",
    "Total_Spending",
    "Total_Purchases",
    "Family_Size",
    "Engagement",
    "Spending_Ratio"
]

df[check_cols].describe()
# Out:
#               Income          Age  Total_Spending  Total_Purchases  \
# count    2209.000000  2209.000000     2209.000000      2209.000000
# mean    51848.126754    57.091897      606.657311        12.558624
# std     21069.624029    11.696191      602.750957         7.208862
# min      1730.000000    30.000000        5.000000         0.000000
# 25%     35196.000000    49.000000       69.000000         6.000000
# 50%     51373.000000    56.000000      396.000000        12.000000
# 75%     68487.000000    67.000000     1047.000000        18.000000
# max    118423.500000    86.000000     2525.000000        32.000000
#
#        Family_Size   Engagement  Spending_Ratio
# count  2209.000000  2209.000000     2209.000000
# mean      1.948393     0.696427        0.009914
# std       0.749431     1.862130        0.016832
# min       1.000000     0.000000        0.000051
# 25%       1.000000     0.125000        0.002346
# 50%       2.000000     0.250000        0.007958
# ...

# %%
print("Marital_Status unique values:")
print(sorted(df["Marital_Status"].unique()))

print("\nEducation unique values:")
print(sorted(df["Education"].unique()))
# Out:
# Marital_Status unique values:
# ['Divorced', 'Married', 'Single', 'Together', 'Widow']
#
# Education unique values:
# ['2n Cycle', 'Basic', 'Graduation', 'Master', 'PhD']

# %%
print("Dt_Customer in columns:", "Dt_Customer" in df.columns)

if "Dt_Customer" in df.columns:
    print(df["Dt_Customer"].head())
# Out:
# Dt_Customer in columns: True
# 0    2012-09-04
# 1    2014-03-08
# 2    2013-08-21
# 3    2014-02-10
# 4    2014-01-19
# Name: Dt_Customer, dtype: object
